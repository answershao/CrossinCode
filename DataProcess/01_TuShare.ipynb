# %% [markdown]
# # Tu Share入门

# %% [markdown]
# ## TuShare快速上手

# %%
import tushare as ts
x = ts.forecast_data(2020,1)

# %%
x
# Out:
#         code   name type report_date  pre_eps            range
# 0     002009   天奇股份   预亏  2020-04-29   0.1000                0
# 1     002074   国轩高科   预减  2020-04-29   0.1800  -84.62%~-83.63%
# 2     002726   龙大肉食   预增  2020-04-29   0.1100          75%~80%
# 3     002122  *ST天马   减亏  2020-04-29  -0.1075                0
# 4     002092   中泰化学   预减  2020-04-29   0.0875  -94.68%~-92.01%
# ...      ...    ...  ...         ...      ...              ...
# 1743  300294   博雅生物   预升  2020-02-03   0.2100           5%~25%
# 1744  002617   露笑科技   预升  2020-01-23   0.0200     0.57%~24.16%
# 1745  300708   聚灿光电   预盈  2020-01-23  -0.0300                0
# 1746  300617   安靠智电   预增  2020-01-17   0.2132     90.4%~114.2%
# 1747  000818   航锦科技   预升  2020-01-16   0.1600   -11.05%~17.99%
#
# [1748 rows x 6 columns]

# %%
x[x.code=='002009']
# Out:
#        code  name type report_date  pre_eps range
# 0    002009  天奇股份   预亏  2020-04-29      0.1     0
# 148  002009  天奇股份   预亏  2020-04-15      0.1     0

# %%
dahua = ts.get_hist_data('002236')
dahua.head(10)
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2020-06-19  18.90  19.22  18.94  18.63   560572.00         -0.04     -0.21
# 2020-06-18  18.50  19.25  18.98  18.50   855677.06          0.57      3.10
# 2020-06-17  18.55  18.88  18.41  18.28   632886.56          0.11      0.60
# 2020-06-16  17.78  18.46  18.30  17.69   886800.62          0.85      4.87
# 2020-06-15  17.80  17.98  17.45  17.45   509529.03         -0.48     -2.68
# 2020-06-12  16.80  18.11  17.93  16.75   951762.56          0.79      4.61
# 2020-06-11  17.58  17.74  17.14  17.08   463122.47         -0.44     -2.50
# 2020-06-10  17.67  17.70  17.58  17.36   394776.12         -0.16     -0.90
# 2020-06-09  17.67  17.85  17.74  17.31   525859.75          0.17      0.97
# 2020-06-08  16.99  18.15  17.57  16.97  1008380.94          0.72      4.27
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20
# date
# ...

# %% [markdown]
# ## 统计股票连续增长天数

# %%
'利用TuShare的接口，来获取股票列表基本信息。得到当日排行前10的股票的信息后，为其增加一列数据 —— 这些股票连续上涨的天数'
# Out:
# '利用TuShare的接口，来获取股票列表基本信息。得到当日排行前10的股票的信息后，为其增加一列数据 —— 这些股票连续上涨的天数'

# %% [markdown]
# ### 主要Tushare接口

# %%
import tushare as ts
# pro version
ts.set_token('b59e1711ac5103e1112f06d03713c5381af610f91f546a8689179ba7')
pro = ts.pro_api()

# old version
total_stock_information = ts.get_stock_basics()
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2

# %%
stocks = total_stock_information.head(10)
stocks
# Out:
#         name industry area      pe  outstanding  totals  totalAssets  \
# code
# 688505   N复旦     化学制药   上海    0.00         0.91   10.43        14.67
# 300824   N北鼎     家用电器   深圳   21.42         0.54    2.17         4.24
# 688157  松井股份     染料涂料   湖南  162.51         0.18    0.80         5.35
# 600828  茂业商业       百货   四川   26.05         6.55   17.32       186.13
# 000691  亚太实业     区域地产   甘肃   79.59         2.90    3.23         2.53
# 600814  杭州解百       百货   浙江    0.00         7.15    7.15        54.11
# 000155  川能动力     新型电力   四川   11.39        12.70   12.70        73.78
# 000638  万方发展     软件服务   吉林    0.00         3.09    3.09         5.19
# 002565  顺灏股份       造纸   上海    0.00        10.56   10.60        29.50
# 600415  小商品城      商品城   浙江   28.36        54.43   54.43       316.10
#
#         liquidAssets  fixedAssets  reserved  ...   bvps     pb  timeToMarket  \
# code                                         ...
# ...

# %%
stocks['raiseDays'] = 0
stocks
# Out:
# C:\Users\shpf_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         name industry area      pe  outstanding  totals  totalAssets  \
# code
# 688505   N复旦     化学制药   上海    0.00         0.91   10.43        14.67
# 300824   N北鼎     家用电器   深圳   21.42         0.54    2.17         4.24
# 688157  松井股份     染料涂料   湖南  162.51         0.18    0.80         5.35
# 600828  茂业商业       百货   四川   26.05         6.55   17.32       186.13
# 000691  亚太实业     区域地产   甘肃   79.59         2.90    3.23         2.53
# 600814  杭州解百       百货   浙江    0.00         7.15    7.15        54.11
# 000155  川能动力     新型电力   四川   11.39        12.70   12.70        73.78
# ...

# %%
current_stock = stocks.iloc[0]
current_stock
# Out:
# name                     N复旦
# industry                化学制药
# area                      上海
# pe                         0
# outstanding             0.91
# totals                 10.43
# totalAssets            14.67
# liquidAssets           10.11
# fixedAssets             2.46
# reserved                2.38
# reservedPerShare        0.23
# esp                   -0.018
# bvps                    1.75
# pb                     21.17
# timeToMarket        20200619
# undp                    4.86
# perundp                 0.47
# rev                        0
# profit                     0
# gpr                    86.75
# npr                   -52.67
# holders                60875
# raiseDays                  0
# Name: 688505, dtype: object

# %%
code = current_stock.name
history
